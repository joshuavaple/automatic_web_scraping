# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
pages = [i for i in range(1, 11)]
urls = ['https://www.fleetmon.com/maritime-news/?page=' + str(page) + '&category=incidents' for page in pages]
urls
# Out:
# ['https://www.fleetmon.com/maritime-news/?page=1&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=2&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=3&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=4&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=5&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=6&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=7&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=8&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=9&category=incidents',
#  'https://www.fleetmon.com/maritime-news/?page=10&category=incidents']

# %%
pages = [i for i in range(1, 11)]
urls = ['https://www.fleetmon.com/maritime-news/?page=' + str(page) + '&category=incidents' for page in pages]
domain = 'https://www.fleetmon.com'
hrefs = []

for url in urls:
    # Send a GET request to the URL
    response = requests.get(url, verify=False)
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all anchor tags (i.e., <a> tags) in the HTML content
    for link in soup.find_all('a', {'class': 'continue-reading'}):
        href = domain + link.get('href')
        hrefs.append(href)
hrefs
# Out:
# c:\Users\JOSHUALE\Documents\GitHub\riskmonitor\venv\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.fleetmon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\JOSHUALE\Documents\GitHub\riskmonitor\venv\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.fleetmon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
def getArticleTexts(urls: list):
    results = {'title':[], 'body':[], 'url':[]}
    for url in urls:
        results['url'].append(url)
        response = requests.get(url, verify = False)
        # Use BeautifulSoup to parse the HTML content of the response
        soup = BeautifulSoup(response.content, 'html.parser')
        h1_tags = soup.find_all('h1')
        header_text = ''
        for h1_tag in h1_tags:
            header_text += h1_tag.get_text()
        results['title'].append(header_text)
        # Find all the <p> tags and extract the longest text, which is the article body most of the time
        p_tags = soup.find_all('p')
        article_texts = []
        for p_tag in p_tags:
            article_texts.append(p_tag.get_text())
        results['body'].append(max(article_texts, key=len))
    return results

# %%
results = getArticleTexts(urls = hrefs)
# Out:
# c:\Users\JOSHUALE\Documents\GitHub\riskmonitor\venv\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.fleetmon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\JOSHUALE\Documents\GitHub\riskmonitor\venv\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.fleetmon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
df_articles = pd.DataFrame(results)
df_articles
# Out:
#                                                  title  \
# 0    \nFSO stern flooded, evac, 1 worker died, Gulf...
# 1    \nContainer ship MSC LAUSANNE anchored in Vigo...
# 2    \nChinese Panamax bulker towed to safety after...
# 3    \n​  Bulk carrier disabled by water ingress at...
# 4             \nPanamax bulk carrier aground, Brazil\n
# ..                                                 ...
# 195     \nPanamax bulk carrier disabled in Bosphorus\n
# 196                      \nCoaster grounding, Norway\n
# 197                    \nPRIDE OF KENT fire, Dunkirk\n
# 198  \nSupertanker in load aground in Singapore Str...
# 199           \nBulk carrier fire, Piraeus Anchorage\n
#
#                                                   body  \
# 0    \n1230 UTC UPDATE: Confirmed it was an explosi...
# 1    \nContainer ship MSC LAUSANNE on arrival from ...
# 2    \nBulk carrier FUPING suffered engine failure ...
# 3    \nBulk carrier LOYALTY HONG, berthed at Lyttel...
# ...

# %%
df_articles.to_excel('fleetmon.xlsx')

# %%
url = hrefs[2]
# url = 'https://www.independent.co.uk/news/world/europe/berlin-protest-greece-refugees-moria-fire-migrants-b507763.html'

# Send a GET request to the URL and store the response
response = requests.get(url, verify = False)

# Use BeautifulSoup to parse the HTML content of the response
soup = BeautifulSoup(response.content, 'html.parser')

h1_tags = soup.find_all('h1')
header_text = ''
for h1_tag in h1_tags:
    header_text += h1_tag.get_text()
# Find all the <p> tags and extract the text
p_tags = soup.find_all('p')
article_texts = []

for p_tag in p_tags:
    article_texts.append(p_tag.get_text())

# p_tag_first = p_tags[0]
# article_text += p_tag_first.get_text()

# Print the article text
print(header_text)
print('='*50)
for text in article_texts:
    print(text)
print('='*50)
print(max(article_texts, key=len))
# Out:
# c:\Users\JOSHUALE\Documents\GitHub\riskmonitor\venv\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.fleetmon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Chinese bulk carrier abandoned in Tatar Strait, sank PHOTOS
#
# ...
# Keep an eye on all your vessels with My Fleet
# Live Tracking in your browser or mobile app with FleetMon Explorer
# Receive alerts on events for your port and vessels with My Alerts
# Create zones and monitor your areas of interest with My Zones
# Calculate the CO2 emission for arbitrary date ranges of a vessel
# Follow any vessel's past track
# Plan ahead with vessel schedules
# See a vessel's predicted route and estimated time of arrival
# Check data regarding time of arrival and departure per Port & Vessel
# ...

# %%
# Out:
# Container ship HAI SU 6 and general cargo ship MISAKI MARU collided at around 0635 Tokyo time Mar 2 in front of Higashi-Ogishima port, Yokohama, Japan. Both ships were on the same route from Tokyo to Yokohama. MISAKI MARU, loaded with steel, sustained starboard side bow damages, HAI SU 6 suffered portside stern breach above waterline. Both ships remained capable of sailing under own power, HAI SU 6 reached destination and was berthed at 0815 Tokyo time, while MISAKI MARU was anchored near collision site.
# New FleetMon Vessel Safety Risk Reports Available: https://www.fleetmon.com/services/vessel-risk-rating/
